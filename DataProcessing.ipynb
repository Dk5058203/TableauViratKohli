# %% [markdown]
# <a href="https://colab.research.google.com/github/Dk5058203/TableauViratKohli/blob/main/DataProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/ipl_match_info_data.csv")
df
# Out:
#      match_id   season        date        city  \
# 0      335982  2007/08  2008-04-18   Bangalore
# 1      335983  2007/08  2008-04-19  Chandigarh
# 2      335984  2007/08  2008-04-19       Delhi
# 3      335985  2007/08  2008-04-20      Mumbai
# 4      335986  2007/08  2008-04-20     Kolkata
# ..        ...      ...         ...         ...
# 945   1304116     2022  2022-05-22      Mumbai
# 946   1312197     2022  2022-05-24     Kolkata
# 947   1312198     2022  2022-05-25     Kolkata
# 948   1312199     2022  2022-05-27   Ahmedabad
# 949   1312200     2022  2022-05-29   Ahmedabad
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla             Delhi Daredevils
# 3                              Wankhede Stadium               Mumbai Indians
# ...

# %%
df1=df[df['team1']=='Royal Challengers Bangalore']
df1
# Out:
#      match_id   season        date       city  \
# 0      335982  2007/08  2008-04-18  Bangalore
# 10     335992  2007/08  2008-04-26  Bangalore
# 14     335996  2007/08  2008-04-28  Bangalore
# 24     336006  2007/08  2008-05-05  Bangalore
# 30     336012  2007/08  2008-05-28  Bangalore
# ..        ...      ...         ...        ...
# 918   1304089     2022  2022-04-30     Mumbai
# 924   1304095     2022  2022-05-04       Pune
# 929   1304100     2022  2022-05-08     Mumbai
# 947   1312198     2022  2022-05-25    Kolkata
# 948   1312199     2022  2022-05-27  Ahmedabad
#
#                                              venue  \
# 0                            M Chinnaswamy Stadium
# 10                           M Chinnaswamy Stadium
# 14                           M Chinnaswamy Stadium
# 24                           M Chinnaswamy Stadium
# 30                           M Chinnaswamy Stadium
# ..                                             ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126 entries, 0 to 948
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_id         126 non-null    int64
#  1   season           126 non-null    object
#  2   date             126 non-null    object
#  3   city             117 non-null    object
#  4   venue            126 non-null    object
#  5   team1            126 non-null    object
#  6   team2            126 non-null    object
#  7   toss_winner      126 non-null    object
#  8   toss_decision    126 non-null    object
#  9   player_of_match  123 non-null    object
#  10  winner           121 non-null    object
#  11  winner_wickets   126 non-null    int64
#  12  winner_runs      126 non-null    int64
#  13  outcome          5 non-null      object
#  14  result_type      126 non-null    object
#  15  results          126 non-null    int64
#  16  gender           126 non-null    object
# ...

# %%
df1.describe()
# Out:
#            match_id  winner_wickets  winner_runs     results  match_number
# count  1.260000e+02      126.000000   126.000000  126.000000    114.000000
# mean   8.137310e+05        3.349206    16.087302   19.436508     29.535088
# std    3.507749e+05        3.411316    30.645853   29.020406     17.585281
# min    3.359820e+05        0.000000     0.000000    0.000000      1.000000
# 25%    4.396742e+05        0.000000     0.000000    6.000000     14.000000
# 50%    8.297280e+05        4.000000     0.000000    7.000000     31.000000
# 75%    1.178403e+06        6.750000    17.000000   17.000000     43.000000
# max    1.312199e+06       10.000000   144.000000  144.000000     70.000000

# %%
DF=pd.read_csv("/content/ipl_match_ball_by_ball_data.csv")
DF
# Out:
# <ipython-input-6-84ea46eea1e6>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   DF=pd.read_csv("/content/ipl_match_ball_by_ball_data.csv")
#         match_id   season  start_date                             venue  \
# 0         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 1         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 2         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 3         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 4         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# ...          ...      ...         ...                               ...
# 225949   1312200     2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225950   1312200     2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225951   1312200     2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# ...

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   match_id                225954 non-null  int64
#  1   season                  225954 non-null  object
#  2   start_date              225954 non-null  object
#  3   venue                   225954 non-null  object
#  4   innings                 225954 non-null  int64
#  5   ball                    225954 non-null  float64
#  6   batting_team            225954 non-null  object
#  7   bowling_team            225954 non-null  object
#  8   striker                 225954 non-null  object
#  9   non_striker             225954 non-null  object
#  10  bowler                  225954 non-null  object
#  11  runs_off_bat            225954 non-null  int64
#  12  extras                  225954 non-null  int64
#  13  wides                   7026 non-null    float64
# ...

# %%
DF2=DF[DF['batting_team']=='Royal Challengers Bangalore']
DF2
# Out:
#         match_id   season  start_date                             venue  \
# 124       335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 125       335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 126       335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 127       335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 128       335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# ...          ...      ...         ...                               ...
# 225607   1312199     2022  2022-05-27  Narendra Modi Stadium, Ahmedabad
# 225608   1312199     2022  2022-05-27  Narendra Modi Stadium, Ahmedabad
# 225609   1312199     2022  2022-05-27  Narendra Modi Stadium, Ahmedabad
# 225610   1312199     2022  2022-05-27  Narendra Modi Stadium, Ahmedabad
# 225611   1312199     2022  2022-05-27  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball                 batting_team           bowling_team  \
# ...

# %%
DF[DF['batting_team'] == 'Royal Challengers Bangalore']['striker'].unique()
DF
# Out:
#         match_id   season  start_date                             venue  \
# 0         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 1         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 2         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 3         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 4         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# ...          ...      ...         ...                               ...
# 225949   1312200     2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225950   1312200     2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225951   1312200     2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225952   1312200     2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225953   1312200     2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball           batting_team                 bowling_team  \
# ...

# %%
kohli = 'V Kohli'

# %%
df3=DF2[DF2['striker']=='V Kohli']
df3
# Out:
#         match_id   season  start_date                             venue  \
# 132       335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 133       335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 134       335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 137       335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 138       335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# ...          ...      ...         ...                               ...
# 225489   1312199     2022  2022-05-27  Narendra Modi Stadium, Ahmedabad
# 225490   1312199     2022  2022-05-27  Narendra Modi Stadium, Ahmedabad
# 225493   1312199     2022  2022-05-27  Narendra Modi Stadium, Ahmedabad
# 225494   1312199     2022  2022-05-27  Narendra Modi Stadium, Ahmedabad
# 225495   1312199     2022  2022-05-27  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball                 batting_team           bowling_team  \
# ...

# %%
df4=df3['total_runs_scored'] = df3['runs_off_bat'].sum()
df4
# Out:
# <ipython-input-10-4d3b92ab7318>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4=df3['total_runs_scored'] = df3['runs_off_bat'].sum()
# 6634

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5266 entries, 132 to 225495
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   match_id                5266 non-null   int64
#  1   season                  5266 non-null   object
#  2   start_date              5266 non-null   object
#  3   venue                   5266 non-null   object
#  4   innings                 5266 non-null   int64
#  5   ball                    5266 non-null   float64
#  6   batting_team            5266 non-null   object
#  7   bowling_team            5266 non-null   object
#  8   striker                 5266 non-null   object
#  9   non_striker             5266 non-null   object
#  10  bowler                  5266 non-null   object
#  11  runs_off_bat            5266 non-null   int64
#  12  extras                  5266 non-null   int64
#  13  wides                   133 non-null    float64
# ...

# %%
df3.to_csv(r'rcb.csv',index=False,header=True)

# %%
with pd.ExcelWriter('RCB.xlsx',mode='a',engine='openpyxl',if_sheet_exists='replace') as writer:
  df3.to_excel(writer,sheet_name='Sheet2')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-39cb163aafd9> in <module>
# ----> 1 with pd.ExcelWriter('RCB.xlsx',mode='a',engine='openpyxl',if_sheet_exists='replace') as writer:
#       2   df3.to_excel(writer,sheet_name='Sheet2')
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/excel/_openpyxl.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      51         engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      52
# ---> 53         super().__init__(
#      54             path,
#      55             mode=mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/excel/_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1104         )
# ...

# %%
df3.describe()
# Out:
#            match_id      innings         ball  runs_off_bat       extras  \
# count  5.266000e+03  5266.000000  5266.000000   5266.000000  5266.000000
# mean   8.655011e+05     1.460691     8.439290      1.259780     0.045955
# std    3.139222e+05     0.503051     5.134895      1.552416     0.283406
# min    3.359820e+05     1.000000     0.100000      0.000000     0.000000
# 25%    5.483620e+05     1.000000     4.200000      0.000000     0.000000
# 50%    9.809140e+05     1.000000     8.200000      1.000000     0.000000
# 75%    1.175369e+06     2.000000    12.375000      1.000000     0.000000
# max    1.312199e+06     4.000000    19.700000      6.000000     5.000000
#
#             wides  noballs     byes    legbyes  penalty  other_wicket_type  \
# count  133.000000     18.0  4.00000  42.000000      0.0                0.0
# mean     1.195489      1.0  1.50000   1.404762      NaN                NaN
# std      0.838999      0.0  0.57735   0.989198      NaN                NaN
# ...
